# %% [markdown]
# ## blog-making-notes 2025-02-11
# - Reconciling local repo at: /Users/mike/Repos/mmossing.github.io
# With github:  [My Journeys](https://mmossing.github.io/)
# Beautiful Jekyll package, jekyll 4.3.3
# Switch to github-pages gem?

# %% [markdown]
# # From Gemini (1 month trial starting today 250211
# How to switch to the github-pages gem (if you decide to):

# %%
# Remove existing Jekyll gem: If you have Jekyll installed separately, uninstall it:
# Bash

# !gem uninstall jekyll
# Out:
# You have requested to uninstall the gem:
# 	jekyll-4.3.3
#
# jekyll-feed-0.17.0 depends on jekyll (>= 3.7, < 5.0)
# jekyll-seo-tag-2.8.0 depends on jekyll (>= 3.8, < 5.0)
# jekyll-sitemap-1.4.0 depends on jekyll (>= 3.7, < 5.0)
# minima-2.5.1 depends on jekyll (>= 3.5, < 5.0)
# If you remove this gem, these dependencies will not be met.
# Continue with Uninstall? [yN]

# %% [markdown]
# Add the github-pages gem to your Gemfile:
#
# Ruby
#
# gem "github-pages"
# Install the gems:
#
# Bash
#
# bundle install
# Update your .gitignore (if necessary): Make sure your .gitignore file includes Gemfile.lock.
#
# Commit the changes:
#
# Bash
#
# git add Gemfile Gemfile.lock
# git commit -m "Switched to github-pages gem"
# git push origin main
#
# By using the github-pages gem, you'll align your local Jekyll environment with the one used by GitHub Pages, which will make your deployments smoother and more reliable.  If you have already been having issues with the image not updating this would be a good step to take.

# %% [markdown]
# [ChatGPT advice](https://chatgpt.com/share/67ab93e8-938c-8003-a3ce-c104dca86b54)
# Steps to Proceed
# 	1. Open  /Users/mike/Repos/mmossing.github.io/Gemfile in bbedit
#     2. Add the Gem to Your Gemfile:
#         - Add this line
#             gem 'github-pages'
#     3.	Install the Dependencies with Bundler:
#         - Save the Gemfile and then run:
#                 bundle install
#                 - see output below
#     4.	Serve Your Site Locally:
#         - Once the gems are installed, you can build and serve your site locally with:
#         bundle exec jekyll serve

# %%
## output from bundle install reflecting the new github-pages gem
```
(base) mike@Michaels-MacBook-Air-2 mmossing.github.io % bundle install
Fetching gem metadata from https://rubygems.org/.........
Resolving dependencies...
Fetching bigdecimal 3.1.9
Fetching benchmark 0.4.0
Fetching connection_pool 2.5.0
Fetching logger 1.6.5
Fetching minitest 5.25.4
Fetching drb 2.2.1
Fetching securerandom 0.4.1
Fetching base64 0.2.0
Installing bigdecimal 3.1.9 with native extensions
Installing benchmark 0.4.0
Fetching csv 3.3.2
Installing connection_pool 2.5.0
Fetching mercenary 0.3.6 (was 0.4.0)
Installing logger 1.6.5
Fetching rouge 3.30.0 (was 4.3.0)
Installing minitest 5.25.4
Fetching coffee-script-source 1.12.2
Installing drb 2.2.1
Fetching execjs 2.10.0
Installing securerandom 0.4.1
Fetching commonmarker 0.23.11
Installing base64 0.2.0
Fetching simpleidn 0.2.3
Installing csv 3.3.2
Fetching uri 1.0.2
Installing mercenary 0.3.6 (was 0.4.0)
Fetching json 2.10.1
Installing rouge 3.30.0 (was 4.3.0)
Installing coffee-script-source 1.12.2
Fetching gemoji 4.1.0
Installing execjs 2.10.0
Fetching racc 1.8.1
Fetching rubyzip 2.4.1
Installing commonmarker 0.23.11 with native extensions
Installing simpleidn 0.2.3
Fetching jekyll-swiss 1.0.0
Installing uri 1.0.2
Fetching unicode-display_width 1.8.0 (was 2.5.0)
Installing json 2.10.1 with native extensions
Installing gemoji 4.1.0
Fetching tzinfo 2.0.6
Installing racc 1.8.1 with native extensions
Installing rubyzip 2.4.1
Fetching ethon 0.16.0
Installing jekyll-swiss 1.0.0
Fetching coffee-script 2.4.1
Installing unicode-display_width 1.8.0 (was 2.5.0)
Fetching dnsruby 1.72.3
Installing tzinfo 2.0.6
Fetching net-http 0.6.0
Installing ethon 0.16.0
Fetching sass-listen 4.0.0
Installing coffee-script 2.4.1
Fetching terminal-table 1.8.0 (was 3.0.2)
Installing dnsruby 1.72.3
Fetching typhoeus 1.4.1
Installing net-http 0.6.0
Fetching jekyll-coffeescript 1.2.2
Installing sass-listen 4.0.0
Fetching faraday-net_http 3.4.0
Installing terminal-table 1.8.0 (was 3.0.2)
Fetching sass 3.7.4
Installing typhoeus 1.4.1
Installing jekyll-coffeescript 1.2.2
Installing faraday-net_http 3.4.0
Installing sass 3.7.4
Fetching jekyll-sass-converter 1.5.2 (was 3.0.0)
Installing jekyll-sass-converter 1.5.2 (was 3.0.0)
Fetching jekyll 3.10.0 (was 4.3.3)
Installing jekyll 3.10.0 (was 4.3.3)
Fetching jekyll-avatar 0.8.0
Fetching jekyll-default-layout 0.1.5
Fetching jekyll-optional-front-matter 0.3.2
Fetching jekyll-include-cache 0.2.1
Installing jekyll-avatar 0.8.0
Fetching jekyll-readme-index 0.3.0
Installing jekyll-default-layout 0.1.5
Fetching jekyll-redirect-from 0.16.0
Installing jekyll-optional-front-matter 0.3.2
Fetching jekyll-relative-links 0.6.1
Installing jekyll-include-cache 0.2.1
Fetching jekyll-remote-theme 0.4.3
Installing jekyll-readme-index 0.3.0
Fetching jekyll-titles-from-headings 0.5.3
Installing jekyll-redirect-from 0.16.0
Fetching jekyll-theme-architect 0.2.0
Installing jekyll-relative-links 0.6.1
Fetching jekyll-theme-cayman 0.2.0
Installing jekyll-remote-theme 0.4.3
Fetching jekyll-theme-dinky 0.2.0
Installing jekyll-titles-from-headings 0.5.3
Fetching jekyll-theme-hacker 0.2.0
Installing jekyll-theme-architect 0.2.0
Fetching jekyll-theme-leap-day 0.2.0
Installing jekyll-theme-cayman 0.2.0
Fetching jekyll-theme-merlot 0.2.0
Installing jekyll-theme-dinky 0.2.0
Fetching jekyll-theme-midnight 0.2.0
Installing jekyll-theme-hacker 0.2.0
Fetching jekyll-theme-minimal 0.2.0
Installing jekyll-theme-leap-day 0.2.0
Fetching jekyll-theme-modernist 0.2.0
Installing jekyll-theme-merlot 0.2.0
Fetching jekyll-theme-slate 0.2.0
Installing jekyll-theme-midnight 0.2.0
Fetching jekyll-theme-tactile 0.2.0
Installing jekyll-theme-minimal 0.2.0
Fetching jekyll-theme-time-machine 0.2.0
Installing jekyll-theme-modernist 0.2.0
Installing jekyll-theme-slate 0.2.0
Installing jekyll-theme-tactile 0.2.0
Installing jekyll-theme-time-machine 0.2.0
Fetching nokogiri 1.18.2 (arm64-darwin)
Fetching jekyll-commonmark 1.4.0
Installing jekyll-commonmark 1.4.0
Fetching jekyll-commonmark-ghpages 0.5.1
Installing jekyll-commonmark-ghpages 0.5.1
Installing nokogiri 1.18.2 (arm64-darwin)
Fetching faraday 2.12.2
Installing faraday 2.12.2
Fetching sawyer 0.9.2
Installing sawyer 0.9.2
Fetching octokit 4.25.1
Installing octokit 4.25.1
Fetching github-pages-health-check 1.18.2
Fetching jekyll-gist 1.5.0
Fetching jekyll-github-metadata 2.16.1
Installing github-pages-health-check 1.18.2
Installing jekyll-gist 1.5.0
Installing jekyll-github-metadata 2.16.1
Fetching jekyll-theme-primer 0.6.0
Installing jekyll-theme-primer 0.6.0
Fetching activesupport 7.2.2.1
Installing activesupport 7.2.2.1
Fetching html-pipeline 2.14.3
Installing html-pipeline 2.14.3
Fetching jekyll-mentions 1.6.0
Fetching jemoji 0.13.0
Installing jekyll-mentions 1.6.0
Installing jemoji 0.13.0
Fetching github-pages 232
Installing github-pages 232
Bundle complete! 5 Gemfile dependencies, 103 gems now installed.
Use `bundle info [gemname]` to see where a bundled gem is installed.
Post-install message from sass:

Ruby Sass has reached end-of-life and should no longer be used.

* If you use Sass as a command-line tool, we recommend using Dart Sass, the new
  primary implementation: https://sass-lang.com/install

* If you use Sass as a plug-in for a Ruby web framework, we recommend using the
  sassc gem: https://github.com/sass/sassc-ruby#readme

* For more details, please refer to the Sass blog:
  https://sass-lang.com/blog/posts/7828841

Post-install message from dnsruby:
Installing dnsruby...
  For issues and source code: https://github.com/alexdalitz/dnsruby
  For general discussion (please tell us how you use dnsruby): https://groups.google.com/forum/#!forum/dnsruby
Post-install message from html-pipeline:
-------------------------------------------------
Thank you for installing html-pipeline!
You must bundle Filter gem dependencies.
See html-pipeline README.md for more details.
https://github.com/jch/html-pipeline#dependencies
-------------------------------------------------
Post-install message from rubyzip:
RubyZip 3.0 is coming!
**********************

The public API of some Rubyzip classes has been modernized to use named
parameters for optional arguments. Please check your usage of the
following classes:
  * `Zip::File`
  * `Zip::Entry`
  * `Zip::InputStream`
  * `Zip::OutputStream`
  * `Zip::DOSTime`

Run your test suite with the `RUBYZIP_V3_API_WARN` environment
variable set to see warnings about usage of the old API. This will
help you to identify any changes that you need to make to your code.
See https://github.com/rubyzip/rubyzip/wiki/Updating-to-version-3.x for
more information.

Please ensure that your Gemfiles and .gemspecs are suitably restrictive
to avoid an unexpected breakage when 3.0 is released (e.g. ~> 2.3.0).
See https://github.com/rubyzip/rubyzip for details. The Changelog also
lists other enhancements and bugfixes that have been implemented since
version 2.3.0.
```
